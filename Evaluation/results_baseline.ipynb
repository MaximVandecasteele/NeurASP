# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # RGB baseline learning curve

# %%
file_path = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_rgb/rgb_run1.csv'
file_path2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_rgb/rgb_run2.csv'
file_path3 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_rgb/rgb_run3.csv'
file_path4 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_rgb/rgb_run4.csv'
file_path5 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_rgb/rgb_run5.csv'

# %%
df1 = pd.read_csv(file_path).drop('Wall time', axis=1)
df2 = pd.read_csv(file_path2).drop('Wall time', axis=1)
df3 = pd.read_csv(file_path3).drop('Wall time', axis=1)
df4 = pd.read_csv(file_path4).drop('Wall time', axis=1)
df5 = pd.read_csv(file_path5).drop('Wall time', axis=1)

# %%
df1['episode']
# Out:
# 0         5
# 1        18
# 2        24
# 3        40
# 4        42
#        ...
# 995    4976
# 996    4977
# 997    4991
# 998    4997
# 999    4999
# Name: episode, Length: 1000, dtype: int64

# %%
value_columns = [df['reward'] for df in [df1, df2, df3, df4, df5]]
concatenated_values = pd.concat(value_columns, axis=1)
result_df = pd.DataFrame(concatenated_values.mean(axis=1), columns=['mean_value'])
result_df_rgb_training = pd.concat([df1['episode'], result_df], axis=1)

# %%
result_df_rgb_training
# Out:
#      episode  mean_value
# 0          5       312.6
# 1         18       320.2
# 2         24       620.6
# 3         40       407.6
# 4         42       322.6
# ..       ...         ...
# 995     4976      2790.4
# 996     4977      1779.2
# 997     4991      2172.8
# 998     4997      2660.8
# 999     4999      2164.6
#
# [1000 rows x 2 columns]

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='episode', y='mean_value', data=result_df_rgb_training, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward')
plt.title('Average Total reward per Episode')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
result_df_rgb_training['ewm'] = result_df_rgb_training.ewm(alpha=0.1).mean()['mean_value']

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='episode', y='ewm', data=result_df_rgb_training, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.title('Average Total Reward per Episode (EWM)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # ASP Baseline learning curve

# %%
file_path_asp = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_asp/asp_run1.csv'
file_path_asp_2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_asp/asp_run2.csv'
file_path_asp_3 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_asp/asp_run3.csv'
file_path_asp_4 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_asp/asp_run4.csv'
file_path_asp_5 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_asp/asp_run5.csv'

# %%
df_asp_1 = pd.read_csv(file_path_asp)
df_asp_2 = pd.read_csv(file_path_asp_2)
df_asp_3 = pd.read_csv(file_path_asp_3)
df_asp_4 = pd.read_csv(file_path_asp_4)
df_asp_5 = pd.read_csv(file_path_asp_5)

# %%
df_asp_1['episode']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 4995    4996
# 4996    4997
# 4997    4998
# 4998    4999
# 4999    5000
# Name: episode, Length: 5000, dtype: int64

# %%
value_columns = [df['reward'] for df in [df_asp_1, df_asp_2, df_asp_3, df_asp_4, df_asp_5]]
concatenated_values = pd.concat(value_columns, axis=1)
result_df = pd.DataFrame(concatenated_values.mean(axis=1), columns=['mean_value'])
result_df_asp_training = pd.concat([df_asp_1['episode'], result_df], axis=1)

# %%
result_df_asp_training
# Out:
#       episode  mean_value
# 0         1.0       905.0
# 1         2.0       394.4
# 2         3.0       508.8
# 3         4.0       394.6
# 4         5.0       322.6
# ...       ...         ...
# 7995      NaN      1728.0
# 7996      NaN      1861.0
# 7997      NaN      3050.0
# 7998      NaN      1923.0
# 7999      NaN      1453.0
#
# [8000 rows x 2 columns]

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='episode', y='mean_value', data=result_df_asp_training, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward')
plt.title('Average Total reward per Episode')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
result_df_asp_training['ewm'] = result_df_asp_training.ewm(alpha=0.1).mean()['mean_value']

# %%
# Set Seaborn style
sns.set_style("whitegrid")



# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='episode', y='ewm', data=result_df_asp_training, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.title('Average Total Reward per Episode (EWM)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # comparison learning curves

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=result_df_rgb_training, x='episode', y='ewm', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=result_df_asp_training, x='episode', y='ewm', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total Reward (EWM)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# matching the episode count for with tensorboard stored episodes

# %%
merged_df = pd.merge(result_df_rgb_training, result_df_asp_training, on='episode', how='inner')

# %%
merged_df
# Out:
#      episode  mean_value_x        ewm_x  mean_value_y        ewm_y
# 0          5         312.6   312.600000         322.6   481.345047
# 1         18         320.2   316.600000         245.6   331.468041
# 2         24         620.6   428.777122         440.4   367.681135
# 3         40         407.6   422.619192         654.6   572.119621
# 4         42         322.6   398.195077         563.2   583.594274
# ..       ...           ...          ...           ...          ...
# 995     4976        2790.4  2292.485119        1577.0  1751.623323
# 996     4977        1779.2  2241.156607        1927.8  1769.240991
# 997     4991        2172.8  2234.320946        1517.6  1790.334570
# 998     4997        2660.8  2276.968851        1827.2  1729.152850
# 999     4999        2164.6  2265.731966        2175.6  1848.771808
#
# [1000 rows x 5 columns]

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=merged_df, x='episode', y='ewm_x', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=merged_df, x='episode', y='ewm_y', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Performance RGB

# %%
file_path_performance_rgb = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_rgb/data_performance_rgb.csv'

# %%
df_performance_rgb = pd.read_csv(file_path_performance_rgb)

# %%
average_rewards_df = df_performance_rgb.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df
# Out:
#      run  model  average_reward
# 0      1    100          854.58
# 1      1    200          816.44
# 2      1    300          638.06
# 3      1    400          750.12
# 4      1    500          679.60
# ..   ...    ...             ...
# 245    5   4600         2561.33
# 246    5   4700         1527.59
# 247    5   4800         2501.65
# 248    5   4900         1979.69
# 249    5   5000         2437.00
#
# [250 rows x 3 columns]

# %%
model_average_rewards_df = average_rewards_df.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_df
# Out:
#     model  average_reward
# 0     100         582.296
# 1     200         768.000
# 2     300         738.894
# 3     400         922.170
# 4     500         797.064
# 5     600         649.014
# 6     700         793.526
# 7     800         844.878
# 8     900         950.524
# 9    1000        1031.194
# 10   1100        1093.928
# 11   1200         945.460
# 12   1300        1185.628
# 13   1400         902.730
# 14   1500        1386.730
# 15   1600        1370.750
# 16   1700        1392.338
# 17   1800        1326.892
# 18   1900        1276.648
# 19   2000        1558.776
# 20   2100        1455.568
# 21   2200        1709.590
# 22   2300        1799.418
# 23   2400        1802.520
# 24   2500        2118.128
# 25   2600        2095.908
# 26   2700        1440.632
# 27   2800        2096.594
# 28   2900        2317.352
# 29   3000        1924.640
# 30   3100        1904.784
# 31   3200        2198.220
# 32   3300        2296.660
# 33   3400        2468.108
# 34   3500        2044.924
# 35   3600        2242.824
# 36   3700        2020.436
# 37   3800        2068.856
# 38   3900        2288.172
# 39   4000        2229.916
# 40   4100        2491.476
# 41   4200        2347.288
# 42   4300        2138.336
# 43   4400        2458.244
# 44   4500        1654.782
# 45   4600        2398.428
# 46   4700        1617.226
# 47   4800        1699.000
# 48   4900        1943.530
# 49   5000        2424.118

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_df, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # Percentage finish

# %%
df_performance_rgb
# Out:
#        run  model  step  reward   flag
# 0        1    100     1   578.0  False
# 1        1    100     2   250.0  False
# 2        1    100     3   797.0  False
# 3        1    100     4   609.0  False
# 4        1    100     5  1048.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96  3049.0   True
# 24996    5   5000    97  3062.0   True
# 24997    5   5000    98  3055.0   True
# 24998    5   5000    99  3060.0   True
# 24999    5   5000   100  1929.0  False
#
# [25000 rows x 5 columns]

# %%
df_finish_rgb = pd.read_csv(file_path_performance_rgb) 
percentage_flag_df = df_finish_rgb.groupby(['run', 'model'])['flag'].mean().reset_index()

percentage_flag_df.rename(columns={'flag': 'percentage_flag'}, inplace=True)

# %%
percentage_flag_df
# Out:
#      run  model  percentage_flag
# 0      1    100             0.00
# 1      1    200             0.00
# 2      1    300             0.00
# 3      1    400             0.00
# 4      1    500             0.00
# ..   ...    ...              ...
# 245    5   4600             0.64
# 246    5   4700             0.08
# 247    5   4800             0.53
# 248    5   4900             0.32
# 249    5   5000             0.37
#
# [250 rows x 3 columns]

# %%
average_percentage_flag_df = percentage_flag_df.groupby('model')['percentage_flag'].mean().reset_index()

# %%
average_percentage_flag_df
# Out:
#     model  percentage_flag
# 0     100            0.000
# 1     200            0.000
# 2     300            0.000
# 3     400            0.000
# 4     500            0.000
# 5     600            0.000
# 6     700            0.000
# 7     800            0.000
# 8     900            0.000
# 9    1000            0.000
# 10   1100            0.000
# 11   1200            0.000
# 12   1300            0.000
# 13   1400            0.002
# 14   1500            0.008
# 15   1600            0.006
# 16   1700            0.038
# 17   1800            0.016
# 18   1900            0.036
# 19   2000            0.046
# 20   2100            0.060
# 21   2200            0.162
# 22   2300            0.226
# 23   2400            0.148
# 24   2500            0.190
# 25   2600            0.206
# 26   2700            0.194
# 27   2800            0.354
# 28   2900            0.476
# 29   3000            0.296
# 30   3100            0.248
# 31   3200            0.388
# 32   3300            0.442
# 33   3400            0.606
# 34   3500            0.362
# 35   3600            0.434
# 36   3700            0.334
# 37   3800            0.368
# 38   3900            0.444
# 39   4000            0.362
# 40   4100            0.592
# 41   4200            0.538
# 42   4300            0.450
# 43   4400            0.572
# 44   4500            0.242
# 45   4600            0.486
# 46   4700            0.170
# 47   4800            0.230
# 48   4900            0.388
# 49   5000            0.516

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='percentage_flag', data=average_percentage_flag_df, sort=False)
plt.xlabel('Episode')
plt.ylabel('Percentage_flag')
plt.title('')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # Performance ASP

# %%
file_path_performance_asp = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_asp/data_performance_asp.csv'

# %%
df_performance_asp = pd.read_csv(file_path_performance_asp)

# %%
df_performance_asp
# Out:
#        run  model  step  reward   flag
# 0        1    100     1  1046.0  False
# 1        1    100     2   635.0  False
# 2        1    100     3   632.0  False
# 3        1    100     4   631.0  False
# 4        1    100     5   635.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96  1336.0  False
# 24996    5   5000    97  3047.0   True
# 24997    5   5000    98  1343.0  False
# 24998    5   5000    99  1771.0  False
# 24999    5   5000   100  3030.0   True
#
# [25000 rows x 5 columns]

# %%
average_rewards_asp_df = df_performance_asp.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_asp_df.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_asp_df
# Out:
#      run  model  average_reward
# 0      1    100          645.42
# 1      1    200          930.43
# 2      1    300         1020.46
# 3      1    400         1184.12
# 4      1    500          744.64
# ..   ...    ...             ...
# 245    5   4600         2340.59
# 246    5   4700         1172.71
# 247    5   4800         2070.99
# 248    5   4900         1671.16
# 249    5   5000         1957.21
#
# [250 rows x 3 columns]

# %%
model_average_rewards_asp_df = average_rewards_asp_df.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_asp_df
# Out:
#     model  average_reward
# 0     100         609.092
# 1     200         532.856
# 2     300         740.930
# 3     400         931.300
# 4     500         838.046
# 5     600         725.118
# 6     700         843.486
# 7     800        1074.552
# 8     900        1154.490
# 9    1000        1052.476
# 10   1100        1047.784
# 11   1200        1281.558
# 12   1300         896.656
# 13   1400        1073.634
# 14   1500        1066.858
# 15   1600        1445.880
# 16   1700        1287.286
# 17   1800        1248.182
# 18   1900        1354.264
# 19   2000        1372.138
# 20   2100        1184.712
# 21   2200        1365.536
# 22   2300        1455.944
# 23   2400        1455.830
# 24   2500        1286.142
# 25   2600        1603.610
# 26   2700        1526.000
# 27   2800        1965.328
# 28   2900        1641.472
# 29   3000        1685.794
# 30   3100        1900.210
# 31   3200        1807.744
# 32   3300        1954.536
# 33   3400        1361.842
# 34   3500        1734.248
# 35   3600        1773.280
# 36   3700        2092.400
# 37   3800        1521.388
# 38   3900        1641.288
# 39   4000        1984.052
# 40   4100        1806.266
# 41   4200        1719.330
# 42   4300        2033.616
# 43   4400        1571.406
# 44   4500        2132.416
# 45   4600        2072.670
# 46   4700        1789.298
# 47   4800        2001.316
# 48   4900        2028.370
# 49   5000        1784.206

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_asp_df, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
#  # Percentage flag

# %%
df_finish_asp = pd.read_csv(file_path_performance_asp) 
percentage_flag_df_asp = df_finish_asp.groupby(['run', 'model'])['flag'].mean().reset_index()

percentage_flag_df_asp.rename(columns={'flag': 'percentage_flag'}, inplace=True)

# %%
average_percentage_flag_df_asp = percentage_flag_df_asp.groupby('model')['percentage_flag'].mean().reset_index()

# %%
average_percentage_flag_df_asp
# Out:
#     model  percentage_flag
# 0     100            0.000
# 1     200            0.000
# 2     300            0.000
# 3     400            0.000
# 4     500            0.000
# 5     600            0.000
# 6     700            0.002
# 7     800            0.006
# 8     900            0.012
# 9    1000            0.010
# 10   1100            0.010
# 11   1200            0.016
# 12   1300            0.004
# 13   1400            0.004
# 14   1500            0.004
# 15   1600            0.080
# 16   1700            0.010
# 17   1800            0.042
# 18   1900            0.042
# 19   2000            0.092
# 20   2100            0.026
# 21   2200            0.046
# 22   2300            0.116
# 23   2400            0.072
# 24   2500            0.024
# 25   2600            0.106
# 26   2700            0.128
# 27   2800            0.234
# 28   2900            0.216
# 29   3000            0.148
# 30   3100            0.260
# 31   3200            0.246
# 32   3300            0.284
# 33   3400            0.134
# 34   3500            0.118
# 35   3600            0.184
# 36   3700            0.310
# 37   3800            0.152
# 38   3900            0.204
# 39   4000            0.290
# 40   4100            0.312
# 41   4200            0.250
# 42   4300            0.320
# 43   4400            0.198
# 44   4500            0.346
# 45   4600            0.372
# 46   4700            0.244
# 47   4800            0.280
# 48   4900            0.338
# 49   5000            0.294

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='percentage_flag', data=average_percentage_flag_df_asp, sort=False)
plt.xlabel('Episode')
plt.ylabel('Percentage_flag')
plt.title('')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # Performance comparison

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=model_average_rewards_df, x='model', y='average_reward', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=model_average_rewards_asp_df, x='model', y='average_reward', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total reward')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Flag percentage comparison

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=average_percentage_flag_df, x='model', y='percentage_flag', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=average_percentage_flag_df_asp, x='model', y='percentage_flag', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Percentage of reaching the flag')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Generalizability RGB

# %%
file_path_generalization_rgb = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_rgb/data_generalization_rgb.csv'

# %%
df_generalization_rgb = pd.read_csv(file_path_generalization_rgb)

# %%
df_generalization_rgb
# Out:
#        run  model  step  reward   flag
# 0        1    100     1   275.0  False
# 1        1    100     2   277.0  False
# 2        1    100     3   367.0  False
# 3        1    100     4   432.0  False
# 4        1    100     5   276.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96   446.0  False
# 24996    5   5000    97   442.0  False
# 24997    5   5000    98   447.0  False
# 24998    5   5000    99   275.0  False
# 24999    5   5000   100   459.0  False
#
# [25000 rows x 5 columns]

# %%
average_rewards_df_generalization = df_generalization_rgb.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_generalization.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_generalization
# Out:
#      run  model  average_reward
# 0      1    100          420.16
# 1      1    200          417.99
# 2      1    300          438.74
# 3      1    400          360.85
# 4      1    500          390.69
# ..   ...    ...             ...
# 245    5   4600          384.78
# 246    5   4700          433.87
# 247    5   4800          349.27
# 248    5   4900          350.18
# 249    5   5000          387.79
#
# [250 rows x 3 columns]

# %%
model_average_rewards_generalization_df = average_rewards_df_generalization.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_generalization_df
# Out:
#     model  average_reward
# 0     100         364.158
# 1     200         423.278
# 2     300         433.314
# 3     400         446.424
# 4     500         433.308
# 5     600         482.332
# 6     700         428.366
# 7     800         435.724
# 8     900         419.744
# 9    1000         450.532
# 10   1100         477.918
# 11   1200         456.884
# 12   1300         470.888
# 13   1400         512.708
# 14   1500         471.246
# 15   1600         465.992
# 16   1700         510.416
# 17   1800         434.624
# 18   1900         441.942
# 19   2000         465.968
# 20   2100         436.440
# 21   2200         481.112
# 22   2300         449.738
# 23   2400         426.044
# 24   2500         437.294
# 25   2600         446.150
# 26   2700         394.028
# 27   2800         412.986
# 28   2900         395.174
# 29   3000         440.746
# 30   3100         387.024
# 31   3200         404.000
# 32   3300         439.370
# 33   3400         418.018
# 34   3500         422.694
# 35   3600         422.334
# 36   3700         391.808
# 37   3800         417.168
# 38   3900         432.858
# 39   4000         417.366
# 40   4100         409.608
# 41   4200         416.628
# 42   4300         411.018
# 43   4400         409.956
# 44   4500         410.406
# 45   4600         413.354
# 46   4700         427.056
# 47   4800         392.016
# 48   4900         388.846
# 49   5000         415.520

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_generalization_df, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # Generalization ASP

# %%
file_path_generalization_asp = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_asp/data_generalization_asp.csv'

# %%
df_generalization_asp = pd.read_csv(file_path_generalization_asp)

# %%
df_generalization_asp
# Out:
#        run  model  step  reward   flag
# 0        1    100     1   276.0  False
# 1        1    100     2   560.0  False
# 2        1    100     3   384.0  False
# 3        1    100     4   842.0  False
# 4        1    100     5   405.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96   277.0  False
# 24996    5   5000    97    75.0  False
# 24997    5   5000    98   260.0  False
# 24998    5   5000    99   276.0  False
# 24999    5   5000   100   277.0  False
#
# [25000 rows x 5 columns]

# %%
average_rewards_df_generalization_asp = df_generalization_asp.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_generalization_asp.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_generalization_asp
# Out:
#      run  model  average_reward
# 0      1    100          424.45
# 1      1    200          359.18
# 2      1    300          512.32
# 3      1    400          452.19
# 4      1    500          502.45
# ..   ...    ...             ...
# 245    5   4600          418.93
# 246    5   4700          395.60
# 247    5   4800          335.37
# 248    5   4900          530.65
# 249    5   5000          366.32
#
# [250 rows x 3 columns]

# %%
model_average_rewards_generalization_df_asp = average_rewards_df_generalization_asp.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_generalization_df_asp
# Out:
#     model  average_reward
# 0     100         408.408
# 1     200         414.528
# 2     300         445.010
# 3     400         480.066
# 4     500         472.284
# 5     600         450.394
# 6     700         413.246
# 7     800         429.850
# 8     900         411.054
# 9    1000         462.590
# 10   1100         504.610
# 11   1200         450.344
# 12   1300         432.970
# 13   1400         461.040
# 14   1500         456.182
# 15   1600         463.122
# 16   1700         477.546
# 17   1800         441.502
# 18   1900         446.180
# 19   2000         460.498
# 20   2100         401.460
# 21   2200         400.674
# 22   2300         470.824
# 23   2400         424.450
# 24   2500         423.652
# 25   2600         427.912
# 26   2700         489.490
# 27   2800         418.622
# 28   2900         496.348
# 29   3000         444.634
# 30   3100         463.188
# 31   3200         456.386
# 32   3300         469.220
# 33   3400         443.536
# 34   3500         459.880
# 35   3600         432.526
# 36   3700         448.656
# 37   3800         457.994
# 38   3900         489.358
# 39   4000         540.530
# 40   4100         493.240
# 41   4200         447.300
# 42   4300         436.572
# 43   4400         433.176
# 44   4500         454.872
# 45   4600         444.522
# 46   4700         420.572
# 47   4800         401.946
# 48   4900         449.650
# 49   5000         455.490

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_generalization_df_asp, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # Generalizability Comparison

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=model_average_rewards_generalization_df, x='model', y='average_reward', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=model_average_rewards_generalization_df_asp, x='model', y='average_reward', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Generalizability RGB 2

# %%
file_path_generalization_rgb_2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_rgb/data_generalization_rgb_2.csv'

# %%
df_generalization_rgb_2 = pd.read_csv(file_path_generalization_rgb_2)

# %%
df_generalization_rgb_2
# Out:
#        run  model  step  reward   flag
# 0        1    100     1   580.0  False
# 1        1    100     2   241.0  False
# 2        1    100     3   831.0  False
# 3        1    100     4   258.0  False
# 4        1    100     5   450.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96   241.0  False
# 24996    5   5000    97   241.0  False
# 24997    5   5000    98   241.0  False
# 24998    5   5000    99   241.0  False
# 24999    5   5000   100   241.0  False
#
# [25000 rows x 5 columns]

# %%
average_rewards_df_generalization_2 = df_generalization_rgb_2.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_generalization_2.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_generalization_2
# Out:
#      run  model  average_reward
# 0      1    100          500.13
# 1      1    200          518.87
# 2      1    300          275.36
# 3      1    400          369.04
# 4      1    500          309.30
# ..   ...    ...             ...
# 245    5   4600          439.60
# 246    5   4700          438.80
# 247    5   4800          365.78
# 248    5   4900          296.58
# 249    5   5000          258.85
#
# [250 rows x 3 columns]

# %%
model_average_rewards_generalization_df_2 = average_rewards_df_generalization_2.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_generalization_df
# Out:
#     model  average_reward
# 0     100         364.158
# 1     200         423.278
# 2     300         433.314
# 3     400         446.424
# 4     500         433.308
# 5     600         482.332
# 6     700         428.366
# 7     800         435.724
# 8     900         419.744
# 9    1000         450.532
# 10   1100         477.918
# 11   1200         456.884
# 12   1300         470.888
# 13   1400         512.708
# 14   1500         471.246
# 15   1600         465.992
# 16   1700         510.416
# 17   1800         434.624
# 18   1900         441.942
# 19   2000         465.968
# 20   2100         436.440
# 21   2200         481.112
# 22   2300         449.738
# 23   2400         426.044
# 24   2500         437.294
# 25   2600         446.150
# 26   2700         394.028
# 27   2800         412.986
# 28   2900         395.174
# 29   3000         440.746
# 30   3100         387.024
# 31   3200         404.000
# 32   3300         439.370
# 33   3400         418.018
# 34   3500         422.694
# 35   3600         422.334
# 36   3700         391.808
# 37   3800         417.168
# 38   3900         432.858
# 39   4000         417.366
# 40   4100         409.608
# 41   4200         416.628
# 42   4300         411.018
# 43   4400         409.956
# 44   4500         410.406
# 45   4600         413.354
# 46   4700         427.056
# 47   4800         392.016
# 48   4900         388.846
# 49   5000         415.520

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_generalization_df_2, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# comparing rgb 0.2 vs 0.02 exp_r

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=model_average_rewards_generalization_df, x='model', y='average_reward', label='0.2')

# Plot the data from df2 using Seaborn
sns.lineplot(data=model_average_rewards_generalization_df_2, x='model', y='average_reward', label='0.02')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total reward')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Generalization ASP 2

# %%
file_path_generalization_asp_2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_run_baseline/csv_asp/data_generalization_asp_2.csv'

# %%
df_generalization_asp_2 = pd.read_csv(file_path_generalization_asp_2)

# %%
df_generalization_asp_2
# Out:
#        run  model  step  reward   flag
# 0        1    100     1   406.0  False
# 1        1    100     2   406.0  False
# 2        1    100     3   406.0  False
# 3        1    100     4   406.0  False
# 4        1    100     5   406.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96   830.0  False
# 24996    5   5000    97   451.0  False
# 24997    5   5000    98   451.0  False
# 24998    5   5000    99   277.0  False
# 24999    5   5000   100   277.0  False
#
# [25000 rows x 5 columns]

# %%
average_rewards_df_generalization_asp_2 = df_generalization_asp_2.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_generalization_asp_2.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_generalization_asp_2
# Out:
#      run  model  average_reward
# 0      1    100          410.48
# 1      1    200          274.37
# 2      1    300          729.25
# 3      1    400          403.84
# 4      1    500          300.80
# ..   ...    ...             ...
# 245    5   4600          295.03
# 246    5   4700          396.71
# 247    5   4800          408.14
# 248    5   4900          776.51
# 249    5   5000          306.98
#
# [250 rows x 3 columns]

# %%
model_average_rewards_generalization_df_asp_2 = average_rewards_df_generalization_asp_2.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_generalization_df_asp_2
# Out:
#     model  average_reward
# 0     100         380.412
# 1     200         310.280
# 2     300         432.402
# 3     400         459.188
# 4     500         366.394
# 5     600         421.248
# 6     700         475.326
# 7     800         389.066
# 8     900         411.722
# 9    1000         486.642
# 10   1100         550.890
# 11   1200         424.846
# 12   1300         380.788
# 13   1400         493.730
# 14   1500         450.684
# 15   1600         456.096
# 16   1700         460.166
# 17   1800         455.122
# 18   1900         391.310
# 19   2000         441.048
# 20   2100         304.054
# 21   2200         521.654
# 22   2300         420.576
# 23   2400         449.172
# 24   2500         351.338
# 25   2600         431.526
# 26   2700         472.984
# 27   2800         379.524
# 28   2900         522.296
# 29   3000         361.884
# 30   3100         428.866
# 31   3200         478.000
# 32   3300         458.888
# 33   3400         473.260
# 34   3500         468.320
# 35   3600         470.650
# 36   3700         513.262
# 37   3800         548.618
# 38   3900         428.076
# 39   4000         677.498
# 40   4100         542.734
# 41   4200         494.632
# 42   4300         459.372
# 43   4400         421.640
# 44   4500         504.230
# 45   4600         391.464
# 46   4700         411.644
# 47   4800         395.388
# 48   4900         447.584
# 49   5000         427.212

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_generalization_df_asp_2, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# comparing rgb 0.2 vs 0.02 exp_r

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=model_average_rewards_generalization_df_asp, x='model', y='average_reward', label='0.2')

# Plot the data from df2 using Seaborn
sns.lineplot(data=model_average_rewards_generalization_df_asp_2, x='model', y='average_reward', label='0.02')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total reward')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Neurasp Naive

# %% [markdown]
# # Neurasp Balanced

# %%
file_path_neurasp_balanced1 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/NeurASP/models/neurasp_lonely/run_1/test.csv'
file_path_neurasp_balanced2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/NeurASP/models/neurasp_lonely/run_2/accuracy_curve.csv'
file_path_neurasp_balanced3 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/NeurASP/models/neurasp_lonely/run_3/accuracy_curve.csv'
file_path_neurasp_balanced4 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/NeurASP/models/neurasp_lonely/run_4/accuracy_curve.csv'
file_path_neurasp_balanced5 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/NeurASP/models/neurasp_lonely/run_5/accuracy_curve.csv'

# %%
neurasp_balanced_1 = pd.read_csv(file_path_neurasp_balanced1) 
neurasp_balanced_2 = pd.read_csv(file_path_neurasp_balanced2) 
neurasp_balanced_3 = pd.read_csv(file_path_neurasp_balanced3) 
neurasp_balanced_4 = pd.read_csv(file_path_neurasp_balanced4) 
neurasp_balanced_5 = pd.read_csv(file_path_neurasp_balanced5)

# %%
accuracy_columns = [df['accuracy'] for df in [neurasp_balanced_1, neurasp_balanced_2, neurasp_balanced_3, neurasp_balanced_4, neurasp_balanced_5]]
concatenated_values = pd.concat(accuracy_columns, axis=1)
result_df = pd.DataFrame(concatenated_values.mean(axis=1), columns=['mean_accuracy'])
result_df_neurasp_balanced = pd.concat([neurasp_balanced_1['epoch'], result_df], axis=1)

# %%
result_df_rgb_training
# Out:
#      episode  mean_value          ewm
# 0          5       312.6   312.600000
# 1         18       320.2   316.600000
# 2         24       620.6   428.777122
# 3         40       407.6   422.619192
# 4         42       322.6   398.195077
# ..       ...         ...          ...
# 995     4976      2790.4  2292.485119
# 996     4977      1779.2  2241.156607
# 997     4991      2172.8  2234.320946
# 998     4997      2660.8  2276.968851
# 999     4999      2164.6  2265.731966
#
# [1000 rows x 3 columns]

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='epoch', y='mean_accuracy', data=result_df_neurasp_balanced, sort=False)
plt.xlabel('Epoch')
plt.ylabel('Average Accuracy')
plt.title('Average Accuracy per Epoch')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
file_path_performance_neurasp_balanced = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/data_performance_neurasp_single.csv'

# %%
df_performance_neurasp_balanced = pd.read_csv(file_path_performance_neurasp_balanced)

# %%
average_rewards_df_neurasp_balanced = df_performance_neurasp_balanced.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_neurasp_balanced.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_neurasp_balanced
# Out:
#      run  model  average_reward
# 0      1      0          491.77
# 1      1      1          445.37
# 2      1      2          460.16
# 3      1      3          432.24
# 4      1      4          515.34
# ..   ...    ...             ...
# 145    5     26          743.43
# 146    5     27          464.45
# 147    5     28          409.83
# 148    5     29          530.12
# 149    5     30          530.41
#
# [150 rows x 3 columns]

# %%
model_average_rewards_neurasp_balanced_df = average_rewards_df_neurasp_balanced.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_neurasp_balanced_df
# Out:
#     model  average_reward
# 0       0         491.770
# 1       1         423.758
# 2       2         483.938
# 3       3         376.368
# 4       4         480.098
# 5       5         356.286
# 6       6         443.068
# 7       7         430.368
# 8       8         381.496
# 9       9         430.624
# 10     10         442.580
# 11     11         481.568
# 12     12         583.140
# 13     13         558.234
# 14     14         619.222
# 15     15         678.774
# 16     16         557.222
# 17     17         561.192
# 18     18         477.964
# 19     19         543.644
# 20     20         511.920
# 21     21         462.406
# 22     22         426.828
# 23     23         543.114
# 24     24         426.900
# 25     25         442.002
# 26     26         513.268
# 27     27         507.812
# 28     28         537.182
# 29     29         558.148
# 30     30         425.340

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_neurasp_balanced_df, sort=False)
plt.xlabel('Epoch')
plt.ylabel('Average Performance')
plt.title('Average Performance per Epoch') # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # NeurASP Pre

# %%
file_path_pre_1 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_pre/neurasp_pre_models/run1/data_asp_run1.csv'
file_path_pre_2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_pre/neurasp_pre_models/run2/data_asp_run2.csv'
file_path_pre_3 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_pre/neurasp_pre_models/run3/data_asp_run3.csv'
file_path_pre_4 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_pre/neurasp_pre_models/run4/data_asp_run4.csv'
file_path_pre_5 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_pre/neurasp_pre_models/run5/data_asp_run5.csv'

# %%
df_pre_1 = pd.read_csv(file_path_pre_1)
df_pre_2 = pd.read_csv(file_path_pre_2)
df_pre_3 = pd.read_csv(file_path_pre_3)
df_pre_4 = pd.read_csv(file_path_pre_4)
df_pre_5 = pd.read_csv(file_path_pre_5)

# %%
value_columns = [df['reward'] for df in [df_pre_1, df_pre_2, df_pre_3, df_pre_4, df_pre_5]]
concatenated_values = pd.concat(value_columns, axis=1)
result_df_pre = pd.DataFrame(concatenated_values.mean(axis=1), columns=['mean_value'])
result_df_pre_training = pd.concat([df_pre_1['episode'], result_df_pre], axis=1)

# %%
result_df_pre_training
# Out:
#       episode  mean_value
# 0           1       472.0
# 1           2       418.0
# 2           3       322.6
# 3           4       235.0
# 4           5       308.2
# ...       ...         ...
# 4995     4996      1542.8
# 4996     4997      1695.8
# 4997     4998       722.4
# 4998     4999      2010.8
# 4999     5000      1184.6
#
# [5000 rows x 2 columns]

# %%
result_df_pre_training['ewm'] = result_df_pre_training.ewm(alpha=0.1).mean()['mean_value']

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='episode', y='ewm', data=result_df_pre_training, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.title('Average Total Reward per Episode (EWM)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=result_df_pre_training, x='episode', y='ewm', label='NeurASP_pre')

# Plot the data from df2 using Seaborn
sns.lineplot(data=result_df_asp_training, x='episode', y='ewm', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total Reward (EWM)')
plt.legend()

# Show the plot
plt.show()

# %%
file_path_performance_neurasp_pre = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/training_pre/data_performance_asp_pre.csv'

# %%
df_performance_neurasp_pre = pd.read_csv(file_path_performance_neurasp_pre)

# %%
average_rewards_df_neurasp_pre = df_performance_neurasp_pre.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_neurasp_pre.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_neurasp_pre
# Out:
#      run  model  average_reward
# 0      1    100          315.45
# 1      1    200          676.98
# 2      1    300          306.27
# 3      1    400          842.45
# 4      1    500          637.31
# ..   ...    ...             ...
# 240    5   4500         1978.56
# 241    5   4600         1607.66
# 242    5   4700         2292.84
# 243    5   4800         1761.67
# 244    5   4900         2669.25
#
# [245 rows x 3 columns]

# %%
model_average_rewards_neurasp_pre_df = average_rewards_df_neurasp_pre.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_neurasp_pre_df
# Out:
#     model  average_reward
# 0     100         282.488
# 1     200         480.244
# 2     300         657.012
# 3     400         859.616
# 4     500         564.702
# 5     600         872.156
# 6     700         576.506
# 7     800         556.180
# 8     900         967.464
# 9    1000         659.370
# 10   1100         992.502
# 11   1200        1173.986
# 12   1300        1061.740
# 13   1400        1078.032
# 14   1500        1346.378
# 15   1600        1230.544
# 16   1700        1170.178
# 17   1800        1189.724
# 18   1900         991.156
# 19   2000        1512.736
# 20   2100        1480.202
# 21   2200        1138.852
# 22   2300        1469.842
# 23   2400        1454.514
# 24   2500        1576.884
# 25   2600        1501.460
# 26   2700        1466.896
# 27   2800        1845.800
# 28   2900        1301.182
# 29   3000        1980.398
# 30   3100        1504.916
# 31   3200        1484.944
# 32   3300        1737.390
# 33   3400        1822.652
# 34   3500        1732.744
# 35   3600        1519.376
# 36   3700        1735.016
# 37   3800        1782.356
# 38   3900        1904.588
# 39   4000        1339.140
# 40   4100        1797.256
# 41   4200        1635.194
# 42   4300        1597.604
# 43   4400        1879.784
# 44   4500        1787.632
# 45   4600        1527.512
# 46   4700        1651.968
# 47   4800        1887.446
# 48   4900        2162.592

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_neurasp_pre_df, sort=False)
plt.xlabel('Epoch')
plt.ylabel('Average Performance')
plt.title('Average Performance per Epoch') # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# Comparison to baseline

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=model_average_rewards_asp_df, x='model', y='average_reward', label='baseline_asp')

# Plot the data from df2 using Seaborn
sns.lineplot(data=model_average_rewards_neurasp_pre_df, x='model', y='average_reward', label='neurasp_pre')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total reward')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # NeurASP Post

# %% [markdown]
# lr = -05

# %%
file_path_performance_neurasp_post_5 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/data_performance_neurasp_post_1e-05.csv'

# %%
df_performance_neurasp_post_5 = pd.read_csv(file_path_performance_neurasp_post_5)

# %%
average_rewards_df_neurasp_post_5 = df_performance_neurasp_post_5.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_neurasp_post_5.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_neurasp_post_5
# Out:
#     run  model  average_reward
# 0     1      1          817.23
# 1     1      2         1173.27
# 2     1      3          906.50
# 3     1      4          776.09
# 4     1      5          833.55
# 5     1      6          916.22
# 6     1      7          969.14
# 7     1      8          338.05
# 8     1      9          296.75
# 9     1     10          259.03
# 10    2      1         1055.58
# 11    2      2          309.53
# 12    2      3          277.84
# 13    2      4          257.12
# 14    2      5          288.73
# 15    2      6          297.74
# 16    2      7          246.67
# 17    2      8          286.14
# 18    2      9          265.41
# 19    2     10          285.15
# 20    3      1         1022.23
# 21    3      2         1154.13
# 22    3      3          360.24
# 23    3      4          724.66
# 24    3      5          717.91
# 25    3      6          652.22
# 26    3      7          638.36
# 27    3      8          654.98
# 28    3      9          778.42
# 29    3     10          674.07
# 30    4      1         1094.49
# 31    4      2          809.88
# 32    4      3         1008.54
# 33    4      4         1004.22
# 34    4      5          886.13
# 35    4      6          856.34
# 36    4      7          947.65
# 37    4      8          968.19
# 38    4      9          869.80
# 39    4     10          825.29
# 40    5      1          831.10
# 41    5      2          369.02
# 42    5      3          685.15
# 43    5      4          827.31
# 44    5      5          338.56
# 45    5      6          639.90
# 46    5      7          601.07
# 47    5      8          544.66
# 48    5      9          289.48
# 49    5     10          341.08

# %%
model_average_rewards_neurasp_post_5_df = average_rewards_df_neurasp_post_5.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_neurasp_post_5_df
# Out:
#    model  average_reward
# 0      1         964.126
# 1      2         763.166
# 2      3         647.654
# 3      4         717.880
# 4      5         612.976
# 5      6         672.484
# 6      7         680.578
# 7      8         558.404
# 8      9         499.972
# 9     10         476.924

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_neurasp_post_5_df, sort=False)
plt.xlabel('Epoch')
plt.ylabel('Average Performance')
plt.title('Average Performance per Epoch') # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# lr = -06

# %%
file_path_performance_neurasp_post_6 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/data_performance_neurasp_post_1e-06.csv'

# %%
df_performance_neurasp_post_6 = pd.read_csv(file_path_performance_neurasp_post_6)

# %%
average_rewards_df_neurasp_post_6 = df_performance_neurasp_post_6.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_neurasp_post_6.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_neurasp_post_6
# Out:
#     run  model  average_reward
# 0     1      1         1928.12
# 1     1      2         1907.44
# 2     1      3         1766.58
# 3     1      4         1052.25
# 4     1      5         1755.79
# 5     1      6         1772.24
# 6     1      7         1547.33
# 7     1      8         1384.86
# 8     1      9         1482.18
# 9     1     10         1456.72
# 10    2      1         1500.80
# 11    2      2         1715.04
# 12    2      3          505.24
# 13    2      4          390.30
# 14    2      5         1589.94
# 15    2      6          431.82
# 16    2      7          360.81
# 17    2      8         1346.07
# 18    2      9         1241.34
# 19    2     10         1103.88
# 20    3      1         2574.54
# 21    3      2         2304.41
# 22    3      3         2447.71
# 23    3      4         1740.66
# 24    3      5         1308.69
# 25    3      6          482.22
# 26    3      7          762.02
# 27    3      8          746.54
# 28    3      9          748.06
# 29    3     10          906.58
# 30    4      1         2212.18
# 31    4      2         2301.91
# 32    4      3         2106.85
# 33    4      4         1146.03
# 34    4      5         1300.61
# 35    4      6         1325.88
# 36    4      7         1391.21
# 37    4      8         1477.64
# 38    4      9         1219.93
# 39    4     10         1302.05
# 40    5      1         1739.39
# 41    5      2         1789.02
# 42    5      3         2136.55
# 43    5      4         2053.60
# 44    5      5         1110.47
# 45    5      6         1093.79
# 46    5      7         1007.83
# 47    5      8          871.60
# 48    5      9          679.15
# 49    5     10          788.03

# %%
model_average_rewards_neurasp_post_6_df = average_rewards_df_neurasp_post_6.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_neurasp_post_6_df
# Out:
#    model  average_reward
# 0      1        1991.006
# 1      2        2003.564
# 2      3        1792.586
# 3      4        1276.568
# 4      5        1413.100
# 5      6        1021.190
# 6      7        1013.840
# 7      8        1165.342
# 8      9        1074.132
# 9     10        1111.452

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_neurasp_post_6_df, sort=False)
plt.xlabel('Epoch')
plt.ylabel('Average Performance')
plt.title('Average Performance per Epoch') # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=model_average_rewards_neurasp_post_5_df, x='model', y='average_reward', label='lr = 1e-05')

# Plot the data from df2 using Seaborn
sns.lineplot(data=model_average_rewards_neurasp_post_6_df, x='model', y='average_reward', label='lr = 1e-06')

# Add labels and legend using Matplotlib

plt.xlabel('Epoch')
plt.ylabel('Total reward')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # This is just a test

# %%
df_test = pd.read_csv('/Users/maximvandecasteele/PycharmProjects/NeurASP/NeurASP/models/asp_ddqn_advisor/run1/data_asp_advisor_run1.csv')

# %%
df_test
# Out:
#       episode  reward
# 0           1   216.0
# 1           2   249.0
# 2           3   602.0
# 3           4  1922.0
# 4           5   631.0
# ...       ...     ...
# 4995     4996  1696.0
# 4996     4997  2360.0
# 4997     4998  1698.0
# 4998     4999  2639.0
# 4999     5000  1922.0
#
# [5000 rows x 2 columns]

# %%
df_test['ewm'] = df_test.ewm(alpha=0.01).mean()['reward']

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='episode', y='ewm', data=df_test, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.title('Average Total Reward per Episode (EWM)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=merged_df, x='episode', y='ewm_x', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=merged_df, x='episode', y='ewm_y', label='ASP')

# Plot the data from df2 using Seaborn
sns.lineplot(data=df_test, x='episode', y='ewm', label='ASP_advisor')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.legend()

# Show the plot
plt.show()
