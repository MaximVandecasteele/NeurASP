# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # RGB baseline learning curve

# %%
file_path = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_rgb/rgb_run1.csv'
file_path2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_rgb/rgb_run2.csv'
file_path3 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_rgb/rgb_run3.csv'
file_path4 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_rgb/rgb_run4.csv'
file_path5 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_rgb/rgb_run5.csv'

# %%
df1 = pd.read_csv(file_path).drop('Wall time', axis=1)
df2 = pd.read_csv(file_path2).drop('Wall time', axis=1)
df3 = pd.read_csv(file_path3).drop('Wall time', axis=1)
df4 = pd.read_csv(file_path4).drop('Wall time', axis=1)
df5 = pd.read_csv(file_path5).drop('Wall time', axis=1)

# %%
df1['episode']
# Out:
# 0         5
# 1        18
# 2        24
# 3        40
# 4        42
#        ...
# 995    4976
# 996    4977
# 997    4991
# 998    4997
# 999    4999
# Name: episode, Length: 1000, dtype: int64

# %%
value_columns = [df['reward'] for df in [df1, df2, df3, df4, df5]]
concatenated_values = pd.concat(value_columns, axis=1)
result_df = pd.DataFrame(concatenated_values.mean(axis=1), columns=['mean_value'])
result_df_rgb_training = pd.concat([df1['episode'], result_df], axis=1)

# %%
result_df_rgb_training
# Out:
#      episode  mean_value
# 0          5       312.6
# 1         18       320.2
# 2         24       620.6
# 3         40       407.6
# 4         42       322.6
# ..       ...         ...
# 995     4976      2790.4
# 996     4977      1779.2
# 997     4991      2172.8
# 998     4997      2660.8
# 999     4999      2164.6
#
# [1000 rows x 2 columns]

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='episode', y='mean_value', data=result_df_rgb_training, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward')
plt.title('Average Total reward per Episode')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
result_df_rgb_training['ewm'] = result_df_rgb_training.ewm(alpha=0.1).mean()['mean_value']

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='episode', y='ewm', data=result_df_rgb_training, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.title('Average Total Reward per Episode (EWM)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # ASP Baseline learning curve

# %%
file_path_asp = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_asp/asp_run1.csv'
file_path_asp_2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_asp/asp_run2.csv'
file_path_asp_3 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_asp/asp_run3.csv'
file_path_asp_4 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_asp/asp_run4.csv'
file_path_asp_5 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_asp/asp_run5.csv'

# %%
df_asp_1 = pd.read_csv(file_path_asp)
df_asp_2 = pd.read_csv(file_path_asp_2)
df_asp_3 = pd.read_csv(file_path_asp_3)
df_asp_4 = pd.read_csv(file_path_asp_4)
df_asp_5 = pd.read_csv(file_path_asp_5)

# %%
df_asp_1['episode']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 4995    4996
# 4996    4997
# 4997    4998
# 4998    4999
# 4999    5000
# Name: episode, Length: 5000, dtype: int64

# %%
value_columns = [df['reward'] for df in [df_asp_1, df_asp_2, df_asp_3, df_asp_4, df_asp_5]]
concatenated_values = pd.concat(value_columns, axis=1)
result_df = pd.DataFrame(concatenated_values.mean(axis=1), columns=['mean_value'])
result_df_asp_training = pd.concat([df_asp_1['episode'], result_df], axis=1)

# %%
result_df_asp_training
# Out:
#       episode  mean_value
# 0         1.0       905.0
# 1         2.0       394.4
# 2         3.0       508.8
# 3         4.0       394.6
# 4         5.0       322.6
# ...       ...         ...
# 7995      NaN      1728.0
# 7996      NaN      1861.0
# 7997      NaN      3050.0
# 7998      NaN      1923.0
# 7999      NaN      1453.0
#
# [8000 rows x 2 columns]

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='episode', y='mean_value', data=result_df_asp_training, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward')
plt.title('Average Total reward per Episode')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
result_df_asp_training['ewm'] = result_df_asp_training.ewm(alpha=0.1).mean()['mean_value']

# %%
# Set Seaborn style
sns.set_style("whitegrid")



# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='episode', y='ewm', data=result_df_asp_training, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.title('Average Total Reward per Episode (EWM)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # comparison learning curves

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=result_df_rgb_training, x='episode', y='ewm', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=result_df_asp_training, x='episode', y='ewm', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total Reward (EWM)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# matching the episode count for with tensorboard stored episodes

# %%
merged_df = pd.merge(result_df_rgb_training, result_df_asp_training, on='episode', how='inner')

# %%
merged_df
# Out:
#      episode  mean_value_x        ewm_x  mean_value_y        ewm_y
# 0          5         312.6   312.600000         322.6   481.345047
# 1         18         320.2   316.600000         245.6   331.468041
# 2         24         620.6   428.777122         440.4   367.681135
# 3         40         407.6   422.619192         654.6   572.119621
# 4         42         322.6   398.195077         563.2   583.594274
# ..       ...           ...          ...           ...          ...
# 995     4976        2790.4  2292.485119        1577.0  1751.623323
# 996     4977        1779.2  2241.156607        1927.8  1769.240991
# 997     4991        2172.8  2234.320946        1517.6  1790.334570
# 998     4997        2660.8  2276.968851        1827.2  1729.152850
# 999     4999        2164.6  2265.731966        2175.6  1848.771808
#
# [1000 rows x 5 columns]

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=merged_df, x='episode', y='ewm_x', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=merged_df, x='episode', y='ewm_y', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Performance RGB

# %%
file_path_performance_rgb = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_rgb/data_performance_rgb.csv'

# %%
df_performance_rgb = pd.read_csv(file_path_performance_rgb)

# %%
average_rewards_df = df_performance_rgb.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df
# Out:
#      run  model  average_reward
# 0      1    100          854.58
# 1      1    200          816.44
# 2      1    300          638.06
# 3      1    400          750.12
# 4      1    500          679.60
# ..   ...    ...             ...
# 245    5   4600         2561.33
# 246    5   4700         1527.59
# 247    5   4800         2501.65
# 248    5   4900         1979.69
# 249    5   5000         2437.00
#
# [250 rows x 3 columns]

# %%
model_average_rewards_df = average_rewards_df.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_df
# Out:
#     model  average_reward
# 0     100         582.296
# 1     200         768.000
# 2     300         738.894
# 3     400         922.170
# 4     500         797.064
# 5     600         649.014
# 6     700         793.526
# 7     800         844.878
# 8     900         950.524
# 9    1000        1031.194
# 10   1100        1093.928
# 11   1200         945.460
# 12   1300        1185.628
# 13   1400         902.730
# 14   1500        1386.730
# 15   1600        1370.750
# 16   1700        1392.338
# 17   1800        1326.892
# 18   1900        1276.648
# 19   2000        1558.776
# 20   2100        1455.568
# 21   2200        1709.590
# 22   2300        1799.418
# 23   2400        1802.520
# 24   2500        2118.128
# 25   2600        2095.908
# 26   2700        1440.632
# 27   2800        2096.594
# 28   2900        2317.352
# 29   3000        1924.640
# 30   3100        1904.784
# 31   3200        2198.220
# 32   3300        2296.660
# 33   3400        2468.108
# ...

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_df, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # Percentage finish

# %%
df_performance_rgb
# Out:
#        run  model  step  reward   flag
# 0        1    100     1   578.0  False
# 1        1    100     2   250.0  False
# 2        1    100     3   797.0  False
# 3        1    100     4   609.0  False
# 4        1    100     5  1048.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96  3049.0   True
# 24996    5   5000    97  3062.0   True
# 24997    5   5000    98  3055.0   True
# 24998    5   5000    99  3060.0   True
# 24999    5   5000   100  1929.0  False
#
# [25000 rows x 5 columns]

# %%
df_finish_rgb = pd.read_csv(file_path_performance_rgb) 
percentage_flag_df = df_finish_rgb.groupby(['run', 'model'])['flag'].mean().reset_index()

percentage_flag_df.rename(columns={'flag': 'percentage_flag'}, inplace=True)

# %%
percentage_flag_df
# Out:
#      run  model  percentage_flag
# 0      1    100             0.00
# 1      1    200             0.00
# 2      1    300             0.00
# 3      1    400             0.00
# 4      1    500             0.00
# ..   ...    ...              ...
# 245    5   4600             0.64
# 246    5   4700             0.08
# 247    5   4800             0.53
# 248    5   4900             0.32
# 249    5   5000             0.37
#
# [250 rows x 3 columns]

# %%
average_percentage_flag_df = percentage_flag_df.groupby('model')['percentage_flag'].mean().reset_index()

# %%
average_percentage_flag_df
# Out:
#     model  percentage_flag
# 0     100            0.000
# 1     200            0.000
# 2     300            0.000
# 3     400            0.000
# 4     500            0.000
# 5     600            0.000
# 6     700            0.000
# 7     800            0.000
# 8     900            0.000
# 9    1000            0.000
# 10   1100            0.000
# 11   1200            0.000
# 12   1300            0.000
# 13   1400            0.002
# 14   1500            0.008
# 15   1600            0.006
# 16   1700            0.038
# 17   1800            0.016
# 18   1900            0.036
# 19   2000            0.046
# 20   2100            0.060
# 21   2200            0.162
# 22   2300            0.226
# 23   2400            0.148
# 24   2500            0.190
# 25   2600            0.206
# 26   2700            0.194
# 27   2800            0.354
# 28   2900            0.476
# 29   3000            0.296
# 30   3100            0.248
# 31   3200            0.388
# 32   3300            0.442
# ...

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='percentage_flag', data=average_percentage_flag_df, sort=False)
plt.xlabel('Episode')
plt.ylabel('Percentage_flag')
plt.title('')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # Performance ASP

# %%
file_path_performance_asp = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_asp/data_performance_asp.csv'

# %%
df_performance_asp = pd.read_csv(file_path_performance_asp)

# %%
df_performance_asp
# Out:
#        run  model  step  reward   flag
# 0        1    100     1  1046.0  False
# 1        1    100     2   635.0  False
# 2        1    100     3   632.0  False
# 3        1    100     4   631.0  False
# 4        1    100     5   635.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96  1336.0  False
# 24996    5   5000    97  3047.0   True
# 24997    5   5000    98  1343.0  False
# 24998    5   5000    99  1771.0  False
# 24999    5   5000   100  3030.0   True
#
# [25000 rows x 5 columns]

# %%
average_rewards_asp_df = df_performance_asp.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_asp_df.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_asp_df
# Out:
#      run  model  average_reward
# 0      1    100          645.42
# 1      1    200          930.43
# 2      1    300         1020.46
# 3      1    400         1184.12
# 4      1    500          744.64
# ..   ...    ...             ...
# 245    5   4600         2340.59
# 246    5   4700         1172.71
# 247    5   4800         2070.99
# 248    5   4900         1671.16
# 249    5   5000         1957.21
#
# [250 rows x 3 columns]

# %%
model_average_rewards_asp_df = average_rewards_asp_df.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_asp_df
# Out:
#     model  average_reward
# 0     100         609.092
# 1     200         532.856
# 2     300         740.930
# 3     400         931.300
# 4     500         838.046
# 5     600         725.118
# 6     700         843.486
# 7     800        1074.552
# 8     900        1154.490
# 9    1000        1052.476
# 10   1100        1047.784
# 11   1200        1281.558
# 12   1300         896.656
# 13   1400        1073.634
# 14   1500        1066.858
# 15   1600        1445.880
# 16   1700        1287.286
# 17   1800        1248.182
# 18   1900        1354.264
# 19   2000        1372.138
# 20   2100        1184.712
# 21   2200        1365.536
# 22   2300        1455.944
# 23   2400        1455.830
# 24   2500        1286.142
# 25   2600        1603.610
# 26   2700        1526.000
# 27   2800        1965.328
# 28   2900        1641.472
# 29   3000        1685.794
# 30   3100        1900.210
# 31   3200        1807.744
# 32   3300        1954.536
# 33   3400        1361.842
# ...

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_asp_df, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
#  # Percentage flag

# %%
df_finish_asp = pd.read_csv(file_path_performance_asp) 
percentage_flag_df_asp = df_finish_asp.groupby(['run', 'model'])['flag'].mean().reset_index()

percentage_flag_df_asp.rename(columns={'flag': 'percentage_flag'}, inplace=True)

# %%
average_percentage_flag_df_asp = percentage_flag_df_asp.groupby('model')['percentage_flag'].mean().reset_index()

# %%
average_percentage_flag_df_asp
# Out:
#     model  percentage_flag
# 0     100            0.000
# 1     200            0.000
# 2     300            0.000
# 3     400            0.000
# 4     500            0.000
# 5     600            0.000
# 6     700            0.002
# 7     800            0.006
# 8     900            0.012
# 9    1000            0.010
# 10   1100            0.010
# 11   1200            0.016
# 12   1300            0.004
# 13   1400            0.004
# 14   1500            0.004
# 15   1600            0.080
# 16   1700            0.010
# 17   1800            0.042
# 18   1900            0.042
# 19   2000            0.092
# 20   2100            0.026
# 21   2200            0.046
# 22   2300            0.116
# 23   2400            0.072
# 24   2500            0.024
# 25   2600            0.106
# 26   2700            0.128
# 27   2800            0.234
# 28   2900            0.216
# 29   3000            0.148
# 30   3100            0.260
# 31   3200            0.246
# 32   3300            0.284
# ...

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='percentage_flag', data=average_percentage_flag_df_asp, sort=False)
plt.xlabel('Episode')
plt.ylabel('Percentage_flag')
plt.title('')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # Performance comparison

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=model_average_rewards_df, x='model', y='average_reward', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=model_average_rewards_asp_df, x='model', y='average_reward', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total reward')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Flag percentage comparison

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=average_percentage_flag_df, x='model', y='percentage_flag', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=average_percentage_flag_df_asp, x='model', y='percentage_flag', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Percentage of reaching the flag')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Generalizability RGB

# %%
file_path_generalization_rgb = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_rgb/data_generalization_rgb.csv'

# %%
df_generalization_rgb = pd.read_csv(file_path_generalization_rgb)

# %%
df_generalization_rgb
# Out:
#        run  model  step  reward   flag
# 0        1    100     1   275.0  False
# 1        1    100     2   277.0  False
# 2        1    100     3   367.0  False
# 3        1    100     4   432.0  False
# 4        1    100     5   276.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96   446.0  False
# 24996    5   5000    97   442.0  False
# 24997    5   5000    98   447.0  False
# 24998    5   5000    99   275.0  False
# 24999    5   5000   100   459.0  False
#
# [25000 rows x 5 columns]

# %%
average_rewards_df_generalization = df_generalization_rgb.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_generalization.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_generalization
# Out:
#      run  model  average_reward
# 0      1    100          420.16
# 1      1    200          417.99
# 2      1    300          438.74
# 3      1    400          360.85
# 4      1    500          390.69
# ..   ...    ...             ...
# 245    5   4600          384.78
# 246    5   4700          433.87
# 247    5   4800          349.27
# 248    5   4900          350.18
# 249    5   5000          387.79
#
# [250 rows x 3 columns]

# %%
model_average_rewards_generalization_df = average_rewards_df_generalization.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_generalization_df
# Out:
#     model  average_reward
# 0     100         364.158
# 1     200         423.278
# 2     300         433.314
# 3     400         446.424
# 4     500         433.308
# 5     600         482.332
# 6     700         428.366
# 7     800         435.724
# 8     900         419.744
# 9    1000         450.532
# 10   1100         477.918
# 11   1200         456.884
# 12   1300         470.888
# 13   1400         512.708
# 14   1500         471.246
# 15   1600         465.992
# 16   1700         510.416
# 17   1800         434.624
# 18   1900         441.942
# 19   2000         465.968
# 20   2100         436.440
# 21   2200         481.112
# 22   2300         449.738
# 23   2400         426.044
# 24   2500         437.294
# 25   2600         446.150
# 26   2700         394.028
# 27   2800         412.986
# 28   2900         395.174
# 29   3000         440.746
# 30   3100         387.024
# 31   3200         404.000
# 32   3300         439.370
# 33   3400         418.018
# ...

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_generalization_df, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # Generalization ASP

# %%
file_path_generalization_asp = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_asp/data_generalization_asp.csv'

# %%
df_generalization_asp = pd.read_csv(file_path_generalization_asp)

# %%
df_generalization_asp
# Out:
#        run  model  step  reward   flag
# 0        1    100     1   276.0  False
# 1        1    100     2   560.0  False
# 2        1    100     3   384.0  False
# 3        1    100     4   842.0  False
# 4        1    100     5   405.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96   277.0  False
# 24996    5   5000    97    75.0  False
# 24997    5   5000    98   260.0  False
# 24998    5   5000    99   276.0  False
# 24999    5   5000   100   277.0  False
#
# [25000 rows x 5 columns]

# %%
average_rewards_df_generalization_asp = df_generalization_asp.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_generalization_asp.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_generalization_asp
# Out:
#      run  model  average_reward
# 0      1    100          424.45
# 1      1    200          359.18
# 2      1    300          512.32
# 3      1    400          452.19
# 4      1    500          502.45
# ..   ...    ...             ...
# 245    5   4600          418.93
# 246    5   4700          395.60
# 247    5   4800          335.37
# 248    5   4900          530.65
# 249    5   5000          366.32
#
# [250 rows x 3 columns]

# %%
model_average_rewards_generalization_df_asp = average_rewards_df_generalization_asp.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_generalization_df_asp
# Out:
#     model  average_reward
# 0     100         408.408
# 1     200         414.528
# 2     300         445.010
# 3     400         480.066
# 4     500         472.284
# 5     600         450.394
# 6     700         413.246
# 7     800         429.850
# 8     900         411.054
# 9    1000         462.590
# 10   1100         504.610
# 11   1200         450.344
# 12   1300         432.970
# 13   1400         461.040
# 14   1500         456.182
# 15   1600         463.122
# 16   1700         477.546
# 17   1800         441.502
# 18   1900         446.180
# 19   2000         460.498
# 20   2100         401.460
# 21   2200         400.674
# 22   2300         470.824
# 23   2400         424.450
# 24   2500         423.652
# 25   2600         427.912
# 26   2700         489.490
# 27   2800         418.622
# 28   2900         496.348
# 29   3000         444.634
# 30   3100         463.188
# 31   3200         456.386
# 32   3300         469.220
# 33   3400         443.536
# ...

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_generalization_df_asp, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # Generalizability Comparison

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=model_average_rewards_generalization_df, x='model', y='average_reward', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=model_average_rewards_generalization_df_asp, x='model', y='average_reward', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Generalizability RGB 2

# %%
file_path_generalization_rgb_2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_rgb/data_generalization_rgb_2.csv'

# %%
df_generalization_rgb_2 = pd.read_csv(file_path_generalization_rgb_2)

# %%
df_generalization_rgb_2
# Out:
#        run  model  step  reward   flag
# 0        1    100     1   580.0  False
# 1        1    100     2   241.0  False
# 2        1    100     3   831.0  False
# 3        1    100     4   258.0  False
# 4        1    100     5   450.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96   241.0  False
# 24996    5   5000    97   241.0  False
# 24997    5   5000    98   241.0  False
# 24998    5   5000    99   241.0  False
# 24999    5   5000   100   241.0  False
#
# [25000 rows x 5 columns]

# %%
average_rewards_df_generalization_2 = df_generalization_rgb_2.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_generalization_2.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_generalization_2
# Out:
#      run  model  average_reward
# 0      1    100          500.13
# 1      1    200          518.87
# 2      1    300          275.36
# 3      1    400          369.04
# 4      1    500          309.30
# ..   ...    ...             ...
# 245    5   4600          439.60
# 246    5   4700          438.80
# 247    5   4800          365.78
# 248    5   4900          296.58
# 249    5   5000          258.85
#
# [250 rows x 3 columns]

# %%
model_average_rewards_generalization_df_2 = average_rewards_df_generalization_2.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_generalization_df
# Out:
#     model  average_reward
# 0     100         364.158
# 1     200         423.278
# 2     300         433.314
# 3     400         446.424
# 4     500         433.308
# 5     600         482.332
# 6     700         428.366
# 7     800         435.724
# 8     900         419.744
# 9    1000         450.532
# 10   1100         477.918
# 11   1200         456.884
# 12   1300         470.888
# 13   1400         512.708
# 14   1500         471.246
# 15   1600         465.992
# 16   1700         510.416
# 17   1800         434.624
# 18   1900         441.942
# 19   2000         465.968
# 20   2100         436.440
# 21   2200         481.112
# 22   2300         449.738
# 23   2400         426.044
# 24   2500         437.294
# 25   2600         446.150
# 26   2700         394.028
# 27   2800         412.986
# 28   2900         395.174
# 29   3000         440.746
# 30   3100         387.024
# 31   3200         404.000
# 32   3300         439.370
# 33   3400         418.018
# ...

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_generalization_df_2, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# comparing rgb 0.2 vs 0.02 exp_r

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=model_average_rewards_generalization_df, x='model', y='average_reward', label='0.2')

# Plot the data from df2 using Seaborn
sns.lineplot(data=model_average_rewards_generalization_df_2, x='model', y='average_reward', label='0.02')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total reward')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Generalization ASP 2

# %%
file_path_generalization_asp_2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_asp/data_generalization_asp_2.csv'

# %%
df_generalization_asp_2 = pd.read_csv(file_path_generalization_asp_2)

# %%
df_generalization_asp_2
# Out:
#        run  model  step  reward   flag
# 0        1    100     1   406.0  False
# 1        1    100     2   406.0  False
# 2        1    100     3   406.0  False
# 3        1    100     4   406.0  False
# 4        1    100     5   406.0  False
# ...    ...    ...   ...     ...    ...
# 24995    5   5000    96   830.0  False
# 24996    5   5000    97   451.0  False
# 24997    5   5000    98   451.0  False
# 24998    5   5000    99   277.0  False
# 24999    5   5000   100   277.0  False
#
# [25000 rows x 5 columns]

# %%
average_rewards_df_generalization_asp_2 = df_generalization_asp_2.groupby(['run', 'model'])['reward'].mean().reset_index()

average_rewards_df_generalization_asp_2.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df_generalization_asp_2
# Out:
#      run  model  average_reward
# 0      1    100          410.48
# 1      1    200          274.37
# 2      1    300          729.25
# 3      1    400          403.84
# 4      1    500          300.80
# ..   ...    ...             ...
# 245    5   4600          295.03
# 246    5   4700          396.71
# 247    5   4800          408.14
# 248    5   4900          776.51
# 249    5   5000          306.98
#
# [250 rows x 3 columns]

# %%
model_average_rewards_generalization_df_asp_2 = average_rewards_df_generalization_asp_2.groupby('model')['average_reward'].mean().reset_index()

# %%
model_average_rewards_generalization_df_asp_2
# Out:
#     model  average_reward
# 0     100         380.412
# 1     200         310.280
# 2     300         432.402
# 3     400         459.188
# 4     500         366.394
# 5     600         421.248
# 6     700         475.326
# 7     800         389.066
# 8     900         411.722
# 9    1000         486.642
# 10   1100         550.890
# 11   1200         424.846
# 12   1300         380.788
# 13   1400         493.730
# 14   1500         450.684
# 15   1600         456.096
# 16   1700         460.166
# 17   1800         455.122
# 18   1900         391.310
# 19   2000         441.048
# 20   2100         304.054
# 21   2200         521.654
# 22   2300         420.576
# 23   2400         449.172
# 24   2500         351.338
# 25   2600         431.526
# 26   2700         472.984
# 27   2800         379.524
# 28   2900         522.296
# 29   3000         361.884
# 30   3100         428.866
# 31   3200         478.000
# 32   3300         458.888
# 33   3400         473.260
# ...

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='model', y='average_reward', data=model_average_rewards_generalization_df_asp_2, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Performance')
plt.title('Average Performance per Episode')
plt.xticks(range(0,5001,100),rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# comparing rgb 0.2 vs 0.02 exp_r

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=model_average_rewards_generalization_df_asp, x='model', y='average_reward', label='0.2')

# Plot the data from df2 using Seaborn
sns.lineplot(data=model_average_rewards_generalization_df_asp_2, x='model', y='average_reward', label='0.02')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total reward')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Test neurasp post

# %%
file_path_performance_neurasp_test = '/Users/maximvandecasteele/PycharmProjects/NeurASP/Evaluation/data_generalization_asp_2.csv'

# %%
df_performance_neurasp_test = pd.read_csv(file_path_performance_neurasp_test)

# %%
df_performance_neurasp_test
# Out:
#      run  episode  reward   flag
# 0      1        1  3061.0   True
# 1      1        2  3034.0   True
# 2      1        3  1704.0  False
# 3      1        4  1710.0  False
# 4      1        5   818.0  False
# ..   ...      ...     ...    ...
# 495    5       96  1331.0  False
# 496    5       97  1930.0  False
# 497    5       98  1930.0  False
# 498    5       99  2638.0  False
# 499    5      100  1930.0  False
#
# [500 rows x 4 columns]

# %%
average_rewards_df = df_performance_neurasp_test.groupby(['run'])['reward'].mean().reset_index()

average_rewards_df.rename(columns={'reward': 'average_reward'}, inplace=True)

# %%
average_rewards_df
# Out:
#    run  average_reward
# 0    1         1909.41
# 1    2         1701.12
# 2    3         1741.97
# 3    4         1672.94
# 4    5         1717.98

# %%
model_average_rewards_df = average_rewards_df['average_reward'].mean()

# %%
model_average_rewards_df
# Out:
# 1748.684
