# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # RGB baseline

# %%
file_path = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/tensorboard_rgb/csv/rgb_1.csv'
file_path2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/tensorboard_rgb/csv/rgb_2.csv'
file_path3 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/tensorboard_rgb/csv/rgb_3.csv'
file_path4 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/tensorboard_rgb/csv/rgb_4.csv'
file_path5 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/tensorboard_rgb/csv/rgb_5.csv'

# %%
df1 = pd.read_csv(file_path).drop('Wall time', axis=1)
df2 = pd.read_csv(file_path2).drop('Wall time', axis=1)
df3 = pd.read_csv(file_path3).drop('Wall time', axis=1)
df4 = pd.read_csv(file_path4).drop('Wall time', axis=1)
df5 = pd.read_csv(file_path5).drop('Wall time', axis=1)

# %%
df1['Step']
# Out:
# 0         5
# 1        18
# 2        24
# 3        40
# 4        42
#        ...
# 995    4976
# 996    4977
# 997    4991
# 998    4997
# 999    4999
# Name: Step, Length: 1000, dtype: int64

# %%
value_columns = [df['Value'] for df in [df1, df2, df3, df4, df5]]
concatenated_values = pd.concat(value_columns, axis=1)
result_df = pd.DataFrame(concatenated_values.mean(axis=1), columns=['mean_value'])
result_df1 = pd.concat([df1['Step'], result_df], axis=1)

# %%
result_df1
# Out:
#      Step  mean_value
# 0       5       312.6
# 1      18       320.2
# 2      24       620.6
# 3      40       407.6
# 4      42       322.6
# ..    ...         ...
# 995  4976      2790.4
# 996  4977      1779.2
# 997  4991      2172.8
# 998  4997      2660.8
# 999  4999      2164.6
#
# [1000 rows x 2 columns]

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='Step', y='mean_value', data=result_df1, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward')
plt.title('Average Total reward per Episode')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
result_df1['ewm'] = result_df1.ewm(alpha=0.1).mean()['mean_value']

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='Step', y='ewm', data=result_df1, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.title('Average Total Reward per Episode (EWM)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # ASP Baseline

# %%
file_path = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_data_training/asp_ubuntu1.csv'
file_path2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_data_training/asp_ubuntu2.csv'
file_path3 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_data_training/asp_ubuntu3.csv'
file_path4 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_data_training/asp_ubuntu_4_mac.csv'
file_path5 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/csv_data_training/asp_ubuntu5.csv'

# %%
df1 = pd.read_csv(file_path).drop('Wall time', axis=1)
df2 = pd.read_csv(file_path2).drop('Wall time', axis=1)
df3 = pd.read_csv(file_path3).drop('Wall time', axis=1)
df4 = pd.read_csv(file_path4).drop('Wall time', axis=1)
df5 = pd.read_csv(file_path5).drop('Wall time', axis=1)

# %%
df1['Step']
# Out:
# 0         5
# 1        18
# 2        24
# 3        40
# 4        42
#        ...
# 995    4976
# 996    4977
# 997    4991
# 998    4997
# 999    4999
# Name: Step, Length: 1000, dtype: int64

# %%
value_columns = [df['Value'] for df in [df1, df2, df3, df4, df5]]
concatenated_values = pd.concat(value_columns, axis=1)
result_df = pd.DataFrame(concatenated_values.mean(axis=1), columns=['mean_value'])
result_df2 = pd.concat([df1['Step'], result_df], axis=1)

# %%
result_df2
# Out:
#      Step  mean_value
# 0       5       250.6
# 1      18       476.4
# 2      24       693.8
# 3      40       654.8
# 4      42       770.8
# ..    ...         ...
# 995  4976      1911.6
# 996  4977      1921.4
# 997  4991      1223.0
# 998  4997      1315.6
# 999  4999      1284.2
#
# [1000 rows x 2 columns]

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='Step', y='mean_value', data=result_df2, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward')
plt.title('Average Total reward per Episode')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
result_df2['ewm'] = result_df2.ewm(alpha=0.1).mean()['mean_value']

# %%
# Set Seaborn style
sns.set_style("whitegrid")



# Plot the average reward per model
plt.figure(figsize=(12, 6))  # Adjust size as needed
sns.lineplot(x='Step', y='ewm', data=result_df2, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.title('Average Total Reward per Episode (EWM)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # comparison

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=result_df1, x='Step', y='ewm', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=result_df2, x='Step', y='ewm', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total Reward (EWM)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # generalization

# %%
file_path = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/tensorboard_asp/csv/data_asp_run1.csv'
file_path2 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/tensorboard_asp/csv/data_asp_run2.csv'
file_path3 = '/Users/maximvandecasteele/PycharmProjects/NeurASP/RL/training_run_baseline/tensorboard_asp/csv/data_asp_run3.csv'

# %%
df1 = pd.read_csv(file_path)
df2 = pd.read_csv(file_path2)
df3 = pd.read_csv(file_path3)

# %%
value_columns = [df['Reward'] for df in [df1, df2, df3]]
concatenated_values = pd.concat(value_columns, axis=1)
result_df = pd.DataFrame(concatenated_values.mean(axis=1), columns=['mean_value'])
result_df3 = pd.concat([df1['Episode'], result_df], axis=1)

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='Episode', y='mean_value', data=result_df3, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward')
plt.title('Average Total reward per Episode')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
result_df3['ewm'] = result_df3.ewm(alpha=0.05).mean()['mean_value']

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='Episode', y='ewm', data=result_df3, sort=False)
plt.xlabel('Episode')
plt.ylabel('Average Total Reward (EWM)')
plt.title('Average Total Reward per Episode (EWM)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
# Plot the data from df1 using Seaborn
plt.figure(figsize=(12, 6))

sns.lineplot(data=result_df1, x='Step', y='ewm', label='RGB')

# Plot the data from df2 using Seaborn
sns.lineplot(data=result_df3, x='Episode', y='ewm', label='ASP')

# Add labels and legend using Matplotlib

plt.xlabel('Episode')
plt.ylabel('Total Reward (EWM)')
plt.legend()

# Show the plot
plt.show()
