# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
file_path = '/Users/maximvandecasteele/PycharmProjects/NeurASP/mario_vanilla/B1/eval/performance_B1.csv'

# %%
df = pd.read_csv(file_path)
sorted_df = df.sort_values(by=['model', 'episode'], ascending=True)

# %%
sorted_df
# Out:
#      model  episode  reward  epsilon
# 0     1000        0  1340.0     0.05
# 1     1000        1   639.0     0.05
# 2     1000        2  1319.0     0.05
# 3     1000        3  1428.0     0.05
# 4     1000        4  1141.0     0.05
# ..     ...      ...     ...      ...
# 595  50000       95  1492.0     0.05
# 596  50000       96   608.0     0.05
# 597  50000       97   252.0     0.05
# 598  50000       98   638.0     0.05
# 599  50000       99   638.0     0.05
#
# [5000 rows x 4 columns]

# %%
result_df = sorted_df.groupby('model')['reward'].mean().reset_index()

# %%
result_df
# Out:
#     model   reward
# 0    1000   903.66
# 1    2000   964.68
# 2    3000   890.03
# 3    4000  1022.65
# 4    5000   878.37
# 5    6000   901.00
# 6    7000   769.12
# 7    8000   968.10
# 8    9000  1213.95
# 9   10000  1127.59
# 10  11000  1044.10
# 11  12000  1153.21
# 12  13000  1494.18
# 13  14000  1639.93
# 14  15000   990.76
# 15  16000  1126.63
# 16  17000  1411.94
# 17  18000  1454.93
# 18  19000  1572.91
# 19  20000  1320.45
# 20  21000  1100.39
# 21  22000   911.46
# 22  23000   782.41
# 23  24000  1561.92
# 24  25000  1420.90
# 25  26000  1518.54
# 26  27000  1547.38
# 27  28000   336.38
# 28  29000  1081.02
# 29  30000   757.33
# 30  31000  1443.55
# 31  32000  1365.73
# 32  33000  1151.23
# 33  34000  1504.61
# 34  35000  1480.11
# 35  36000   964.40
# 36  37000  1347.60
# 37  38000  1490.11
# 38  39000  1489.30
# 39  40000  1559.72
# 40  41000  1182.22
# 41  42000  1598.91
# 42  43000  1531.18
# 43  44000  1318.92
# 44  45000  1513.11
# 45  46000  1801.28
# ...

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='model', y='reward', data=result_df, marker='o', sort=False)
plt.xlabel('Model')
plt.ylabel('Average Reward')
plt.title('Average Reward per Model')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
sns.regplot(x='model', y='reward', data=result_df)
# Out:
# <Axes: xlabel='model', ylabel='reward'>

# %%
file_path = '/Users/maximvandecasteele/PycharmProjects/NeurASP/mario_vanilla/B2_one_hot/eval/performance_B2_one_hot.csv'

# %%
df = pd.read_csv(file_path)
sorted_df = df.sort_values(by=['model', 'episode'], ascending=True)

# %%
sorted_df
# Out:
#       model  episode  reward  epsilon
# 0      1000        0   248.0     0.05
# 1      1000        1   634.0     0.05
# 2      1000        2  1008.0     0.05
# 3      1000        3   443.0     0.05
# 4      1000        4   610.0     0.05
# ...     ...      ...     ...      ...
# 4995  50000       95   597.0     0.05
# 4996  50000       96   795.0     0.05
# 4997  50000       97  1044.0     0.05
# 4998  50000       98  1051.0     0.05
# 4999  50000       99  1036.0     0.05
#
# [5000 rows x 4 columns]

# %%
result_df = sorted_df.groupby('model')['reward'].mean().reset_index()

# %%
result_df
# Out:
#     model  reward
# 0    1000  705.11
# 1    2000  691.16
# 2    3000  709.05
# 3    4000  336.29
# 4    5000  751.47
# 5    6000  472.66
# 6    7000  548.39
# 7    8000  471.06
# 8    9000  632.79
# 9   10000  825.40
# 10  11000  815.93
# 11  12000  381.45
# 12  13000  673.52
# 13  14000  816.26
# 14  15000  601.45
# 15  16000  828.89
# 16  17000  713.12
# 17  18000  740.12
# 18  19000  837.95
# 19  20000  714.38
# 20  21000  833.09
# 21  22000  843.29
# 22  23000  917.36
# 23  24000  759.70
# 24  25000  400.17
# 25  26000  898.72
# 26  27000  982.02
# 27  28000  468.64
# 28  29000  684.01
# 29  30000  899.06
# 30  31000  718.52
# 31  32000  707.45
# 32  33000  832.91
# 33  34000  938.09
# 34  35000  757.79
# 35  36000  771.01
# 36  37000  895.07
# 37  38000  801.74
# 38  39000  617.18
# 39  40000  354.92
# 40  41000  834.59
# 41  42000  704.59
# 42  43000  823.77
# 43  44000  800.20
# 44  45000  828.25
# 45  46000  930.81
# 46  47000  869.82
# 47  48000  306.54
# 48  49000  796.12
# ...

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Plot the average reward per model
plt.figure(figsize=(10, 6))  # Adjust size as needed
sns.lineplot(x='model', y='reward', data=result_df, marker='o', sort=False)
plt.xlabel('Model')
plt.ylabel('Average Reward')
plt.title('Average Reward per Model')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
sns.regplot(x='model', y='reward', data=result_df)
# Out:
# <Axes: xlabel='model', ylabel='reward'>
